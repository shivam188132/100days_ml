# %% [markdown]
# How to import data to your library directly from kaggle use this command in blind mode after uploading kaggle.json from ur device.

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %% [markdown]
# after that go to your kaggle file and then click on copy api command

# %% [markdown]
# add ! befor pasting api command here that u copied

# %%
# !kaggle datasets download -d informrohit1/smartphones-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/informrohit1/smartphones-dataset
# License(s): MIT
# ...
#   0% 0.00/23.1k [00:00<?, ?B/s]
# 100% 23.1k/23.1k [00:00<00:00, 42.6MB/s]

# %% [markdown]
# ### that file will be zip file to unzip run this command

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/smartphones-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import pandas as pd
df = pd.read_csv('/content/smartphones_cleaned_v6.csv')

# %%
df.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0           False      snapdragon        8.0              3.2  ...
# 1           False      snapdragon        8.0              2.2  ...
# 2           False          exynos        8.0              2.4  ...
# 3           False      snapdragon        8.0              2.2  ...
# 4           False       dimensity        8.0              2.6  ...
#
#    refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 0           120                 3                1.0  android
# ...
